# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data from Yahoo Finance
#
# Yahoo Finance provides information about public stocks in different markets. The library yfinance gives us access to a fair bit of the data in Yahoo Finance.
#
# These steps are based on the instructions in:
#
# + [yfinance documentation](https://pypi.org/project/yfinance/)
# + [Tutorial in geeksforgeeks.org](https://www.geeksforgeeks.org/get-financial-data-from-yahoo-finance-with-python/)

# %% [markdown]
# + If required, install: `python -m pip install yfinance`.
# + To download the price history of a stock, first use the following setup:

# %%
import pandas as pd
import yfinance as yf
import os
import sys

sys.path.append(os.getenv('SRC_DIR'))

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to download the historical price data for a stock, we could use:

# %%
stock = yf.Ticker("AAPL")
px = stock.history(start = "2013-12-01", end = "2024-02-01")
px
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2013-12-02 00:00:00-05:00   17.405170   17.602615   17.181212   17.194000
# 2013-12-03 00:00:00-05:00   17.414518   17.666551   17.395180   17.664679
# 2013-12-04 00:00:00-05:00   17.639100   17.754199   17.493121   17.623505
# 2013-12-05 00:00:00-05:00   17.862125   17.939793   17.667487   17.713963
# 2013-12-06 00:00:00-05:00   17.648149   17.678094   17.454136   17.468170
# ...                               ...         ...         ...         ...
# 2024-01-25 00:00:00-05:00  194.482008  195.528042  192.379984  193.435974
# 2024-01-26 00:00:00-05:00  193.535609  194.023747  191.214415  191.692596
# 2024-01-29 00:00:00-05:00  191.284144  191.473428  188.863337  191.005203
# 2024-01-30 00:00:00-05:00  190.218194  191.074943  186.761310  187.329147
# 2024-01-31 00:00:00-05:00  186.332931  186.392717  183.653113  183.702911
#
#                               Volume  Dividends  Stock Splits
# Date
# 2013-12-02 00:00:00-05:00  472544800        0.0           0.0
# 2013-12-03 00:00:00-05:00  450968000        0.0           0.0
# 2013-12-04 00:00:00-05:00  377809600        0.0           0.0
# 2013-12-05 00:00:00-05:00  447580000        0.0           0.0
# 2013-12-06 00:00:00-05:00  344352400        0.0           0.0
# ...                              ...        ...           ...
# 2024-01-25 00:00:00-05:00   54822100        0.0           0.0
# 2024-01-26 00:00:00-05:00   44594000        0.0           0.0
# 2024-01-29 00:00:00-05:00   47145600        0.0           0.0
# 2024-01-30 00:00:00-05:00   55859400        0.0           0.0
# 2024-01-31 00:00:00-05:00   55467800        0.0           0.0
#
# [2558 rows x 7 columns]

# %% [markdown]
# ## Parametrize the download
#
# + Generally, we will look to separate every parameter and setting from functions.
# + If we had a few stocks, we could cycle through them. We need a place to store the list of tickers (a db or file, for example).
# + Store a csv file with a few stock tickers. The location of the file is a setting, the contents of this file are parameters.
# + Use **environment variables** to pass parameters.

# %%
ticker_file = os.getenv("TICKERS")
tickers = pd.read_csv(ticker_file).sample(50, random_state=42)
tickers
# Out:
#     ticker                                Security             GICS Sector  \
# 268    JCI                        Johnson Controls             Industrials
# 73     BSX                       Boston Scientific             Health Care
# 289    LIN                               Linde plc               Materials
# 155    DOW                                Dow Inc.               Materials
# 104    CVX                     Chevron Corporation                  Energy
# 280    KHC                             Kraft Heinz        Consumer Staples
# 392     RL                Ralph Lauren Corporation  Consumer Discretionary
# 124     ED                     Consolidated Edison               Utilities
# 68      BX                              Blackstone              Financials
# 244    IBM                                     IBM  Information Technology
# 9        A                    Agilent Technologies             Health Care
# 195    FIS  Fidelity National Information Services              Financials
# 304    MAS                                   Masco             Industrials
# 84     CPB                   Campbell Soup Company        Consumer Staples
# 373    PNW                           Pinnacle West               Utilities
# 390   QCOM                                Qualcomm  Information Technology
# 498    YUM                             Yum! Brands  Consumer Discretionary
# 30     AWK                    American Water Works               Utilities
# 317     MU                       Micron Technology  Information Technology
# 407    RCL                   Royal Caribbean Group  Consumer Discretionary
# 493    WTW                    Willis Towers Watson              Financials
# 494    GWW                          W. W. Grainger             Industrials
# 225    HAS                                  Hasbro  Consumer Discretionary
# 227   PEAK                              Healthpeak             Real Estate
# 76      BR          Broadridge Financial Solutions             Industrials
# 464    VLO                           Valero Energy                  Energy
# 473   VICI                         Vici Properties             Real Estate
# 402    RHI                             Robert Half             Industrials
# 101    CRL              Charles River Laboratories             Health Care
# 335    NEM                                 Newmont               Materials
# 296    LYB                          LyondellBasell               Materials
# 222     GS                           Goldman Sachs              Financials
# 474      V                               Visa Inc.              Financials
# 173   EPAM                            EPAM Systems  Information Technology
# 2      ABT                                  Abbott             Health Care
# 334   NFLX                                 Netflix  Communication Services
# 272   KVUE                                  Kenvue        Consumer Staples
# 70    BKNG                        Booking Holdings  Consumer Discretionary
# 210     IT                                 Gartner  Information Technology
# 63     BBY                                Best Buy  Consumer Discretionary
# 347    NUE                                   Nucor               Materials
# 93    CBRE                              CBRE Group             Real Estate
# 488    WDC                         Western Digital  Information Technology
# 185   EXPE                           Expedia Group  Consumer Discretionary
# 33    AMGN                                   Amgen             Health Care
# 77     BRO                           Brown & Brown              Financials
# 0      MMM                                      3M             Industrials
# 11    ABNB                                  Airbnb  Consumer Discretionary
# 310    MDT                               Medtronic             Health Care
# 22    AMZN                                  Amazon  Consumer Discretionary
#
#                                 GICS Sub-Industry  \
# 268                             Building Products
# 73                          Health Care Equipment
# 289                              Industrial Gases
# 155                           Commodity Chemicals
# 104                          Integrated Oil & Gas
# 280                        Packaged Foods & Meats
# 392           Apparel, Accessories & Luxury Goods
# 124                               Multi-Utilities
# 68               Asset Management & Custody Banks
# 244                IT Consulting & Other Services
# 9                  Life Sciences Tools & Services
# 195     Transaction & Payment Processing Services
# 304                             Building Products
# 84                         Packaged Foods & Meats
# 373                               Multi-Utilities
# 390                                Semiconductors
# 498                                   Restaurants
# 30                                Water Utilities
# 317                                Semiconductors
# 407                Hotels, Resorts & Cruise Lines
# 493                             Insurance Brokers
# 494  Industrial Machinery & Supplies & Components
# 225                              Leisure Products
# 227                             Health Care REITs
# 76          Data Processing & Outsourced Services
# 464                Oil & Gas Refining & Marketing
# 473                          Hotel & Resort REITs
# 402          Human Resource & Employment Services
# 101                Life Sciences Tools & Services
# 335                                          Gold
# 296                           Specialty Chemicals
# 222                Investment Banking & Brokerage
# 474     Transaction & Payment Processing Services
# 173                IT Consulting & Other Services
# 2                           Health Care Equipment
# 334                        Movies & Entertainment
# 272                        Personal Care Products
# 70                 Hotels, Resorts & Cruise Lines
# 210                IT Consulting & Other Services
# 63                  Computer & Electronics Retail
# 347                                         Steel
# 93                           Real Estate Services
# 488    Technology Hardware, Storage & Peripherals
# 185                Hotels, Resorts & Cruise Lines
# 33                                  Biotechnology
# 77                              Insurance Brokers
# 0                        Industrial Conglomerates
# 11                 Hotels, Resorts & Cruise Lines
# 310                         Health Care Equipment
# 22                               Broadline Retail
#
#                            Headquarters Location  Date added      CIK  \
# 268                                Cork, Ireland       40417   833444
# 73                    Marlborough, Massachusetts       34754   885725
# 289                    Guildford, United Kingdom       33786  1707925
# 155                            Midland, Michigan       43556  1751788
# 104                        San Ramon, California       20883    93410
# 280  Chicago, Illinois; Pittsburgh, Pennsylvania       42191  1637459
# 392                      New York City, New York       39115  1037038
# 124                      New York City, New York       20883  1047862
# 68                       New York City, New York       45187  1393818
# 244                             Armonk, New York       20883    51143
# 9                        Santa Clara, California       36682  1090872
# 195                        Jacksonville, Florida       39031  1136893
# 304                            Livonia, Michigan       29767    62996
# 84                            Camden, New Jersey       20883    16732
# 373                             Phoenix, Arizona       36437   764622
# 390                        San Diego, California       36363   804328
# 498                         Louisville, Kentucky       35709  1041061
# 30                            Camden, New Jersey       42433  1410636
# 317                                 Boise, Idaho       34604   723125
# 407                               Miami, Florida       41978   884887
# 493                       London, United Kingdom       42374  1140536
# 494                        Lake Forest, Illinois       29767   277135
# 225                      Pawtucket, Rhode Island       30955    46080
# 227                       Long Beach, California       39538   765880
# 76                        Lake Success, New York       43269  1383312
# 464                           San Antonio, Texas       37610  1035002
# 473                      New York City, New York       44720  1705696
# 402                       Menlo Park, California       36865   315213
# 101                    Wilmington, Massachusetts       44330  1100682
# 335                             Denver, Colorado       25384  1164727
# 296                       Rotterdam, Netherlands       41157  1489393
# 222                      New York City, New York       37459   886982
# 474                    San Francisco, California       40168  1403161
# 173                        Newtown, Pennsylvania       44544  1352010
# 2                        North Chicago, Illinois       20883     1800
# 334                        Los Gatos, California       40532  1065280
# 272                         Skillman, New Jersey       45163  1944048
# 70                          Norwalk, Connecticut       40123  1075531
# 210                        Stamford, Connecticut       42830   749251
# 63                          Richfield, Minnesota       36340   764478
# 347                    Charlotte, North Carolina       31167    73309
# 93                                 Dallas, Texas       39031  1138118
# 488                         San Jose, California       39995   106040
# 185                          Seattle, Washington       39357  1324424
# 33                     Thousand Oaks, California       33605   318154
# 77                        Daytona Beach, Florida       44459    79282
# 0                          Saint Paul, Minnesota       20883    66740
# 11                     San Francisco, California       45187  1559720
# 310                              Dublin, Ireland       31716  1613103
# 22                           Seattle, Washington       38674  1018724
#
#                               Founded
# 268                              1885
# 73                               1979
# 289                              1879
# 155                       2019 (1897)
# 104                              1879
# 280                       2015 (1869)
# 392                              1967
# 124                              1823
# 68                               1985
# 244                              1911
# 9                                1999
# 195                              1968
# 304                              1929
# 84                               1869
# 373                              1985
# 390                              1985
# 498                              1997
# 30                               1886
# 317                              1978
# 407                              1997
# 493                              2016
# 494                              1927
# 225                              1923
# 227                              1985
# 76                               1962
# 464                              1980
# 473                              2017
# 402                              1948
# 101                              1947
# 335                              1921
# 296                              2007
# 222                              1869
# 474                              1958
# 173                              1993
# 2                                1888
# 334                              1997
# 272  2022 (Johnson & Johnson spinoff)
# 70                               1996
# 210                              1979
# 63                               1966
# 347                              1940
# 93                               1906
# 488                              1970
# 185                              1996
# 33                               1980
# 77                               1939
# 0                                1902
# 11                               2008
# 310                              1949
# 22                               1994

# %% [markdown]
# Collecting padas data frames
#
# + From the [documentation](https://pandas.pydata.org/docs/user_guide/merging.html):
#
# > [`concat()`](https://pandas.pydata.org/docs/reference/api/pandas.concat.html#pandas.concat) makes a full copy of the data, and iteratively reusing `concat()` can create unnecessary copies. Collect all DataFrame or Series objects in a list before using `concat()`.
#
# + We can string operation togethers using dot operations. Enclose the line in parenthesis and add linebreaks for readability.

# %%
# List to hold final results
px_list = list()

for k, row in tickers.iterrows():  # Produces an iterator that returns index and row

    stock = yf.Ticker(row['ticker'])
    print(f'Processing {row["ticker"]}')
    
    px = (stock
          .history(start = pd.to_datetime("2013-12-01"), 
                   end = pd.to_datetime("2024-02-01"))
          .reset_index()   # Reset index to get date as a column
          .assign(ticker = row['ticker']))    # Add ticker
    
    if px.shape[0] == 0:
        print(f'No data for {row["ticker"]}')  # Validate: do not fail silently.
        continue
    print(f'Downloaded {px.shape}.')
    px_list.append(px)
px_dt = pd.concat(px_list, axis = 0)
print(f'Final shape {px_dt.shape}.')
# Out:
# Processing JCI
# Downloaded (2558, 9).
# Processing BSX
# Downloaded (2558, 9).
# Processing LIN
# Downloaded (2558, 9).
# Processing DOW
# Downloaded (1226, 9).
# Processing CVX
# Downloaded (2558, 9).
# Processing KHC
# Downloaded (2159, 9).
# Processing RL
# Downloaded (2558, 9).
# Processing ED
# Downloaded (2558, 9).
# Processing BX
# Downloaded (2558, 9).
# Processing IBM
# Downloaded (2558, 9).
# Processing A
# Downloaded (2558, 9).
# Processing FIS
# Downloaded (2558, 9).
# Processing MAS
# Downloaded (2558, 9).
# Processing CPB
# Downloaded (2558, 9).
# Processing PNW
# Downloaded (2558, 9).
# Processing QCOM
# Downloaded (2558, 9).
# Processing YUM
# Downloaded (2558, 9).
# Processing AWK
# Downloaded (2558, 9).
# Processing MU
# Downloaded (2558, 9).
# Processing RCL
# Downloaded (2558, 9).
# Processing WTW
# Downloaded (2558, 9).
# Processing GWW
# Downloaded (2558, 9).
# Processing HAS
# Downloaded (2558, 9).
# Processing PEAK
# $PEAK: possibly delisted; no timezone found
# No data for PEAK
# Processing BR
# Downloaded (2558, 9).
# Processing VLO
# Downloaded (2558, 9).
# Processing VICI
# Downloaded (1530, 9).
# Processing RHI
# Downloaded (2558, 9).
# Processing CRL
# Downloaded (2558, 9).
# Processing NEM
# Downloaded (2558, 9).
# Processing LYB
# Downloaded (2558, 9).
# Processing GS
# Downloaded (2558, 9).
# Processing V
# Downloaded (2558, 9).
# Processing EPAM
# Downloaded (2558, 9).
# Processing ABT
# Downloaded (2558, 9).
# Processing NFLX
# Downloaded (2558, 9).
# Processing KVUE
# Downloaded (187, 9).
# Processing BKNG
# Downloaded (2558, 9).
# Processing IT
# Downloaded (2558, 9).
# Processing BBY
# Downloaded (2558, 9).
# Processing NUE
# Downloaded (2558, 9).
# Processing CBRE
# Downloaded (2558, 9).
# Processing WDC
# Downloaded (2558, 9).
# Processing EXPE
# Downloaded (2558, 9).
# Processing AMGN
# Downloaded (2558, 9).
# Processing BRO
# Downloaded (2558, 9).
# Processing MMM
# Downloaded (2558, 9).
# Processing ABNB
# Downloaded (789, 9).
# Processing MDT
# Downloaded (2558, 9).
# Processing AMZN
# Downloaded (2558, 9).
# Final shape (118443, 9).

# %% [markdown]
# ## Reliability
#
# + Keppelman (2017) defines *reliability* as:
#
#     - A system should continue to work correctly.
#     - To work correctly means performing the correct function at the desired level of performance, even in the face of adversity such as hardware or software faults, and even human error.
#
# + *Faults* are things that can go wrong.
# + Sytems that can cope with (certain types of) faults are called *fault-tolerant* or *resilient*.
# + A fault is different than a failure.
#
#     - A *fault* occurs when a component of the system deviates from spec.
#     - A *failure*  is when the system stops providing the required service to the user.
#
# + In our simple example, we handle the fault that occurs when one ticker is not found and log it using *warning*.

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time

# %%
temp = os.getenv("TEMP_DATA")
os.makedirs(temp, exist_ok=True) # If Dir doesn't exist it will create, if it does exist, it will ignore
stock_path = os.path.join(temp, "stock_px.csv")

# %%
stock_path
# Out:
# '../../05_src/data/temp/stock_px.csv'

# %%
start = time.time()
px_dt.to_csv(stock_path, index = False)
end = time.time()

print(f'Writing to dt ({px_dt.shape})csv took {end - start} seconds.')
print(f'Csv file size { os.path.getsize(stock_path)*1e-6 } MB')
# Out:
# Writing to dt ((118443, 9))csv took 1.8733718395233154 seconds.
# Csv file size 14.154301 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask.dataframe as dd
# Out:
# c:\Users\Test\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\_pyarrow_compat.py:17: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 11.0.0. Please consider upgrading.
#   warnings.warn(
# C:\Users\Test\AppData\Local\Temp\ipykernel_27324\676544213.py:1: DeprecationWarning: The current Dask DataFrame implementation is deprecated.
# In a future release, Dask DataFrame will use new implementation that
# contains several improvements including a logical query planning.
# The user-facing DataFrame API will remain unchanged.
#
# The new implementation is already available and can be enabled by
# installing the dask-expr library:
#
#     $ pip install dask-expr
#
# and turning the query planning option on:
#
#     >>> import dask
#     >>> dask.config.set({'dataframe.query-planning': True})
#     >>> import dask.dataframe as dd
#
# API documentation for the new implementation is available at
# https://docs.dask.org/en/stable/dask-expr-api.html
#
# Any feedback can be reported on the Dask issue tracker
# https://github.com/dask/dask/issues
#
#   import dask.dataframe as dd

# %%
px_dd = dd.from_pandas(px_dt, npartitions = len(tickers))
parquet_path = os.path.join(temp, "stock_px.parquet")

start = time.time()
px_dd.to_parquet(parquet_path, engine = "pyarrow")
end = time.time()

print(f'Writing dd ({px_dt.shape}) to parquet took {end - start} seconds.')
print(f'Parquet file size { get_dir_size(parquet_path)*1e-6 } MB')
# Out:
# Writing dd ((118443, 9)) to parquet took 0.3130173683166504 seconds.
# Parquet file size 5.5621719999999994 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to larrge joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
for ticker in px_dt.ticker.unique():
    ticker_dt = px_dt[px_dt.ticker == ticker]
    ticker_dt = ticker_dt.assign(year = ticker_dt.Date.dt.year)
    for yr in ticker_dt.year.unique():
        yr_dt = ticker_dt[ticker_dt.year == yr]
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}.parquet")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dt.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "*/*.parquet"))
dd_px = dd.read_parquet(parquet_files).set_index("ticker")

# %%
# dask dataframe, lazy execution = dd_px 

dd_px.compute()
# Out:
#                             Date        Open        High         Low  \
# ticker
# A      2013-12-02 00:00:00-05:00   34.875479   35.005926   34.640671
# A      2013-12-03 00:00:00-05:00   34.516752   34.679815   34.281943
# A      2013-12-04 00:00:00-05:00   34.464560   35.110283   34.386293
# A      2013-12-05 00:00:00-05:00   34.797214   35.090723   34.647198
# A      2013-12-06 00:00:00-05:00   35.064621   35.827743   35.064621
# ...                          ...         ...         ...         ...
# YUM    2024-01-25 00:00:00-05:00  127.913548  128.386458  126.642582
# YUM    2024-01-26 00:00:00-05:00  128.002213  128.760851  126.770665
# YUM    2024-01-29 00:00:00-05:00  127.194332  128.622925  126.396276
# YUM    2024-01-30 00:00:00-05:00  128.435707  129.283013  127.667222
# YUM    2024-01-31 00:00:00-05:00  129.509627  130.031802  127.351952
#
#              Close   Volume  Dividends  Stock Splits  year
# ticker
# A        34.705894  2039962        0.0           0.0  2013
# A        34.523273  3462706        0.0           0.0  2013
# A        34.947220  3377288        0.0           0.0  2013
# A        34.895050  2530939        0.0           0.0  2013
# A        35.762520  4268513        0.0           0.0  2013
# ...            ...      ...        ...           ...   ...
# YUM     128.297791  1871700        0.0           0.0  2024
# YUM     127.184464  1157000        0.0           0.0  2024
# YUM     128.622925  1482100        0.0           0.0  2024
# YUM     128.691864  1421500        0.0           0.0  2024
# YUM     127.578568  2154200        0.0           0.0  2024
#
# [118443 rows x 9 columns]

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
import numpy as np
dd_rets = (
    dd_px.groupby('ticker', group_keys=False)
        .apply(
                lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
        ).assign(
                returns = lambda x: x['Close']/x['Close_lag_1'] - 1
        ).assign(
                positive_return = lambda x: (x['returns'] > 0)*1
        ))
# Out:
# C:\Users\Test\AppData\Local\Temp\ipykernel_27324\1047164269.py:3: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_px.groupby('ticker', group_keys=False)

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                                             Date     Open     High      Low    Close Volume Dividends Stock Splits   year Close_lag_1  returns positive_return
# npartitions=49
# A               datetime64[ns, America/New_York]  float64  float64  float64  float64  int64   float64      float64  int32     float64  float64           int32
# ABNB                                         ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# ...                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# YUM                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# YUM                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# Dask Name: assign, 18 graph layers

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#                             Date        Open        High         Low  \
# ticker
# A      2013-12-02 00:00:00-05:00   34.875479   35.005926   34.640671
# A      2013-12-03 00:00:00-05:00   34.516752   34.679815   34.281943
# A      2013-12-04 00:00:00-05:00   34.464560   35.110283   34.386293
# A      2013-12-05 00:00:00-05:00   34.797214   35.090723   34.647198
# A      2013-12-06 00:00:00-05:00   35.064621   35.827743   35.064621
# ...                          ...         ...         ...         ...
# YUM    2024-01-25 00:00:00-05:00  127.913548  128.386458  126.642582
# YUM    2024-01-26 00:00:00-05:00  128.002213  128.760851  126.770665
# YUM    2024-01-29 00:00:00-05:00  127.194332  128.622925  126.396276
# YUM    2024-01-30 00:00:00-05:00  128.435707  129.283013  127.667222
# YUM    2024-01-31 00:00:00-05:00  129.509627  130.031802  127.351952
#
#              Close   Volume  Dividends  Stock Splits  year  Close_lag_1  \
# ticker
# A        34.705894  2039962        0.0           0.0  2013          NaN
# A        34.523273  3462706        0.0           0.0  2013    34.705894
# A        34.947220  3377288        0.0           0.0  2013    34.523273
# A        34.895050  2530939        0.0           0.0  2013    34.947220
# A        35.762520  4268513        0.0           0.0  2013    34.895050
# ...            ...      ...        ...           ...   ...          ...
# YUM     128.297791  1871700        0.0           0.0  2024   127.529312
# YUM     127.184464  1157000        0.0           0.0  2024   128.297791
# YUM     128.622925  1482100        0.0           0.0  2024   127.184464
# YUM     128.691864  1421500        0.0           0.0  2024   128.622925
# YUM     127.578568  2154200        0.0           0.0  2024   128.691864
#
#          returns  positive_return
# ticker
# A            NaN                0
# A      -0.005262                0
# A       0.012280                1
# A      -0.001493                0
# A       0.024859                1
# ...          ...              ...
# YUM     0.006026                1
# YUM    -0.008678                0
# YUM     0.011310                1
# YUM     0.000536                1
# YUM    -0.008651                0
#
# [118443 rows x 12 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before start
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %%
FEATURES_DATA = os.getenv("FEATURES_DATA")
dd_rets.to_parquet(FEATURES_DATA, engine = "pyarrow")

# %% [markdown]
# # A few notes
#
# # Jupyter?
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object oriented programming?
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefits from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# Below, we demonstrate how our class implementation works.
#
# Before we begin, clean the price directory (we will download everything again).

# %%
# CLean up before start

if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %% [markdown]
# Now, instantiate a DataManager object and download all the data.

# %%
from data_manager import DataManager
dm = DataManager()

# %%
dm.download_all()
# Out:
# 2024-10-23 21:01:36,747, data_manager.py, 43, INFO, Getting price data for all tickers.
# 2024-10-23 21:01:36,747, data_manager.py, 43, INFO, Getting price data for all tickers.
# 2024-10-23 21:01:36,759, data_manager.py, 52, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-10-23 21:01:36,759, data_manager.py, 52, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-10-23 21:01:36,776, data_manager.py, 58, INFO, Processing all tickers
# 2024-10-23 21:01:36,776, data_manager.py, 58, INFO, Processing all tickers
# 2024-10-23 21:01:36,779, data_manager.py, 73, INFO, Processing ticker MMM
# 2024-10-23 21:01:36,779, data_manager.py, 73, INFO, Processing ticker MMM
# 2024-10-23 21:01:36,786, data_manager.py, 109, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-10-23
# 2024-10-23 21:01:36,786, data_manager.py, 109, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:01:37,315, data_manager.py, 83, INFO, Saving data for MMM by year
# 2024-10-23 21:01:37,315, data_manager.py, 83, INFO, Saving data for MMM by year
# 2024-10-23 21:01:38,406, data_manager.py, 73, INFO, Processing ticker AOS
# 2024-10-23 21:01:38,406, data_manager.py, 73, INFO, Processing ticker AOS
# 2024-10-23 21:01:38,408, data_manager.py, 109, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-10-23
# 2024-10-23 21:01:38,408, data_manager.py, 109, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:01:38,809, data_manager.py, 83, INFO, Saving data for AOS by year
# 2024-10-23 21:01:38,809, data_manager.py, 83, INFO, Saving data for AOS by year
# 2024-10-23 21:01:39,856, data_manager.py, 73, INFO, Processing ticker ABT
# 2024-10-23 21:01:39,856, data_manager.py, 73, INFO, Processing ticker ABT
# 2024-10-23 21:01:39,858, data_manager.py, 109, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-10-23
# 2024-10-23 21:01:39,858, data_manager.py, 109, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:01:40,160, data_manager.py, 83, INFO, Saving data for ABT by year
# 2024-10-23 21:01:40,160, data_manager.py, 83, INFO, Saving data for ABT by year
# 2024-10-23 21:01:41,142, data_manager.py, 73, INFO, Processing ticker ABBV
# 2024-10-23 21:01:41,142, data_manager.py, 73, INFO, Processing ticker ABBV
# 2024-10-23 21:01:41,145, data_manager.py, 109, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-10-23
# 2024-10-23 21:01:41,145, data_manager.py, 109, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:01:41,369, data_manager.py, 83, INFO, Saving data for ABBV by year
# 2024-10-23 21:01:41,369, data_manager.py, 83, INFO, Saving data for ABBV by year
# 2024-10-23 21:01:41,854, data_manager.py, 73, INFO, Processing ticker ACN
# 2024-10-23 21:01:41,854, data_manager.py, 73, INFO, Processing ticker ACN
# 2024-10-23 21:01:41,855, data_manager.py, 109, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-10-23
# 2024-10-23 21:01:41,855, data_manager.py, 109, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:01:42,181, data_manager.py, 83, INFO, Saving data for ACN by year
# 2024-10-23 21:01:42,181, data_manager.py, 83, INFO, Saving data for ACN by year
# 2024-10-23 21:01:43,335, data_manager.py, 73, INFO, Processing ticker ADBE
# 2024-10-23 21:01:43,335, data_manager.py, 73, INFO, Processing ticker ADBE
# 2024-10-23 21:01:43,338, data_manager.py, 109, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-10-23
# 2024-10-23 21:01:43,338, data_manager.py, 109, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:01:43,709, data_manager.py, 83, INFO, Saving data for ADBE by year
# 2024-10-23 21:01:43,709, data_manager.py, 83, INFO, Saving data for ADBE by year
# 2024-10-23 21:01:45,043, data_manager.py, 73, INFO, Processing ticker AMD
# 2024-10-23 21:01:45,043, data_manager.py, 73, INFO, Processing ticker AMD
# 2024-10-23 21:01:45,046, data_manager.py, 109, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-10-23
# 2024-10-23 21:01:45,046, data_manager.py, 109, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:01:45,346, data_manager.py, 83, INFO, Saving data for AMD by year
# 2024-10-23 21:01:45,346, data_manager.py, 83, INFO, Saving data for AMD by year
# 2024-10-23 21:01:46,726, data_manager.py, 73, INFO, Processing ticker AES
# 2024-10-23 21:01:46,726, data_manager.py, 73, INFO, Processing ticker AES
# 2024-10-23 21:01:46,728, data_manager.py, 109, INFO, Getting stock price data for AES from 2000-01-01 to 2024-10-23
# 2024-10-23 21:01:46,728, data_manager.py, 109, INFO, Getting stock price data for AES from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:01:47,190, data_manager.py, 83, INFO, Saving data for AES by year
# 2024-10-23 21:01:47,190, data_manager.py, 83, INFO, Saving data for AES by year
# 2024-10-23 21:01:48,388, data_manager.py, 73, INFO, Processing ticker AFL
# 2024-10-23 21:01:48,388, data_manager.py, 73, INFO, Processing ticker AFL
# 2024-10-23 21:01:48,390, data_manager.py, 109, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-10-23
# 2024-10-23 21:01:48,390, data_manager.py, 109, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:01:48,797, data_manager.py, 83, INFO, Saving data for AFL by year
# 2024-10-23 21:01:48,797, data_manager.py, 83, INFO, Saving data for AFL by year
# 2024-10-23 21:01:49,950, data_manager.py, 73, INFO, Processing ticker A
# 2024-10-23 21:01:49,950, data_manager.py, 73, INFO, Processing ticker A
# 2024-10-23 21:01:49,952, data_manager.py, 109, INFO, Getting stock price data for A from 2000-01-01 to 2024-10-23
# 2024-10-23 21:01:49,952, data_manager.py, 109, INFO, Getting stock price data for A from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:01:50,304, data_manager.py, 83, INFO, Saving data for A by year
# 2024-10-23 21:01:50,304, data_manager.py, 83, INFO, Saving data for A by year
# 2024-10-23 21:01:51,554, data_manager.py, 73, INFO, Processing ticker APD
# 2024-10-23 21:01:51,554, data_manager.py, 73, INFO, Processing ticker APD
# 2024-10-23 21:01:51,556, data_manager.py, 109, INFO, Getting stock price data for APD from 2000-01-01 to 2024-10-23
# 2024-10-23 21:01:51,556, data_manager.py, 109, INFO, Getting stock price data for APD from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:01:51,988, data_manager.py, 83, INFO, Saving data for APD by year
# 2024-10-23 21:01:51,988, data_manager.py, 83, INFO, Saving data for APD by year
# 2024-10-23 21:01:53,154, data_manager.py, 73, INFO, Processing ticker ABNB
# 2024-10-23 21:01:53,154, data_manager.py, 73, INFO, Processing ticker ABNB
# 2024-10-23 21:01:53,156, data_manager.py, 109, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-10-23
# 2024-10-23 21:01:53,156, data_manager.py, 109, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:01:53,275, data_manager.py, 83, INFO, Saving data for ABNB by year
# 2024-10-23 21:01:53,275, data_manager.py, 83, INFO, Saving data for ABNB by year
# 2024-10-23 21:01:53,520, data_manager.py, 73, INFO, Processing ticker AKAM
# 2024-10-23 21:01:53,520, data_manager.py, 73, INFO, Processing ticker AKAM
# 2024-10-23 21:01:53,522, data_manager.py, 109, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-10-23
# 2024-10-23 21:01:53,522, data_manager.py, 109, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:01:53,782, data_manager.py, 83, INFO, Saving data for AKAM by year
# 2024-10-23 21:01:53,782, data_manager.py, 83, INFO, Saving data for AKAM by year
# 2024-10-23 21:01:55,057, data_manager.py, 73, INFO, Processing ticker ALB
# 2024-10-23 21:01:55,057, data_manager.py, 73, INFO, Processing ticker ALB
# 2024-10-23 21:01:55,059, data_manager.py, 109, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-10-23
# 2024-10-23 21:01:55,059, data_manager.py, 109, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:01:55,578, data_manager.py, 83, INFO, Saving data for ALB by year
# 2024-10-23 21:01:55,578, data_manager.py, 83, INFO, Saving data for ALB by year
# 2024-10-23 21:01:56,760, data_manager.py, 73, INFO, Processing ticker ARE
# 2024-10-23 21:01:56,760, data_manager.py, 73, INFO, Processing ticker ARE
# 2024-10-23 21:01:56,762, data_manager.py, 109, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-10-23
# 2024-10-23 21:01:56,762, data_manager.py, 109, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:01:57,163, data_manager.py, 83, INFO, Saving data for ARE by year
# 2024-10-23 21:01:57,163, data_manager.py, 83, INFO, Saving data for ARE by year
# 2024-10-23 21:01:58,400, data_manager.py, 73, INFO, Processing ticker ALGN
# 2024-10-23 21:01:58,400, data_manager.py, 73, INFO, Processing ticker ALGN
# 2024-10-23 21:01:58,403, data_manager.py, 109, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-10-23
# 2024-10-23 21:01:58,403, data_manager.py, 109, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:01:58,669, data_manager.py, 83, INFO, Saving data for ALGN by year
# 2024-10-23 21:01:58,669, data_manager.py, 83, INFO, Saving data for ALGN by year
# 2024-10-23 21:01:59,826, data_manager.py, 73, INFO, Processing ticker ALLE
# 2024-10-23 21:01:59,826, data_manager.py, 73, INFO, Processing ticker ALLE
# 2024-10-23 21:01:59,829, data_manager.py, 109, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-10-23
# 2024-10-23 21:01:59,829, data_manager.py, 109, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:00,104, data_manager.py, 83, INFO, Saving data for ALLE by year
# 2024-10-23 21:02:00,104, data_manager.py, 83, INFO, Saving data for ALLE by year
# 2024-10-23 21:02:00,683, data_manager.py, 73, INFO, Processing ticker LNT
# 2024-10-23 21:02:00,683, data_manager.py, 73, INFO, Processing ticker LNT
# 2024-10-23 21:02:00,685, data_manager.py, 109, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:00,685, data_manager.py, 109, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:01,120, data_manager.py, 83, INFO, Saving data for LNT by year
# 2024-10-23 21:02:01,120, data_manager.py, 83, INFO, Saving data for LNT by year
# 2024-10-23 21:02:02,307, data_manager.py, 73, INFO, Processing ticker ALL
# 2024-10-23 21:02:02,307, data_manager.py, 73, INFO, Processing ticker ALL
# 2024-10-23 21:02:02,309, data_manager.py, 109, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:02,309, data_manager.py, 109, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:02,729, data_manager.py, 83, INFO, Saving data for ALL by year
# 2024-10-23 21:02:02,729, data_manager.py, 83, INFO, Saving data for ALL by year
# 2024-10-23 21:02:03,886, data_manager.py, 73, INFO, Processing ticker GOOGL
# 2024-10-23 21:02:03,886, data_manager.py, 73, INFO, Processing ticker GOOGL
# 2024-10-23 21:02:03,888, data_manager.py, 109, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:03,888, data_manager.py, 109, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:04,219, data_manager.py, 83, INFO, Saving data for GOOGL by year
# 2024-10-23 21:02:04,219, data_manager.py, 83, INFO, Saving data for GOOGL by year
# 2024-10-23 21:02:05,399, data_manager.py, 73, INFO, Processing ticker GOOG
# 2024-10-23 21:02:05,399, data_manager.py, 73, INFO, Processing ticker GOOG
# 2024-10-23 21:02:05,401, data_manager.py, 109, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:05,401, data_manager.py, 109, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:05,747, data_manager.py, 83, INFO, Saving data for GOOG by year
# 2024-10-23 21:02:05,747, data_manager.py, 83, INFO, Saving data for GOOG by year
# 2024-10-23 21:02:06,838, data_manager.py, 73, INFO, Processing ticker MO
# 2024-10-23 21:02:06,838, data_manager.py, 73, INFO, Processing ticker MO
# 2024-10-23 21:02:06,841, data_manager.py, 109, INFO, Getting stock price data for MO from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:06,841, data_manager.py, 109, INFO, Getting stock price data for MO from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:07,290, data_manager.py, 83, INFO, Saving data for MO by year
# 2024-10-23 21:02:07,290, data_manager.py, 83, INFO, Saving data for MO by year
# 2024-10-23 21:02:08,511, data_manager.py, 73, INFO, Processing ticker AMZN
# 2024-10-23 21:02:08,511, data_manager.py, 73, INFO, Processing ticker AMZN
# 2024-10-23 21:02:08,513, data_manager.py, 109, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:08,513, data_manager.py, 109, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:08,773, data_manager.py, 83, INFO, Saving data for AMZN by year
# 2024-10-23 21:02:08,773, data_manager.py, 83, INFO, Saving data for AMZN by year
# 2024-10-23 21:02:10,103, data_manager.py, 73, INFO, Processing ticker AMCR
# 2024-10-23 21:02:10,103, data_manager.py, 73, INFO, Processing ticker AMCR
# 2024-10-23 21:02:10,105, data_manager.py, 109, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:10,105, data_manager.py, 109, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:10,330, data_manager.py, 83, INFO, Saving data for AMCR by year
# 2024-10-23 21:02:10,330, data_manager.py, 83, INFO, Saving data for AMCR by year
# 2024-10-23 21:02:10,970, data_manager.py, 73, INFO, Processing ticker AEE
# 2024-10-23 21:02:10,970, data_manager.py, 73, INFO, Processing ticker AEE
# 2024-10-23 21:02:10,972, data_manager.py, 109, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:10,972, data_manager.py, 109, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:11,319, data_manager.py, 83, INFO, Saving data for AEE by year
# 2024-10-23 21:02:11,319, data_manager.py, 83, INFO, Saving data for AEE by year
# 2024-10-23 21:02:12,519, data_manager.py, 73, INFO, Processing ticker AAL
# 2024-10-23 21:02:12,519, data_manager.py, 73, INFO, Processing ticker AAL
# 2024-10-23 21:02:12,522, data_manager.py, 109, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:12,522, data_manager.py, 109, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:12,806, data_manager.py, 83, INFO, Saving data for AAL by year
# 2024-10-23 21:02:12,806, data_manager.py, 83, INFO, Saving data for AAL by year
# 2024-10-23 21:02:13,802, data_manager.py, 73, INFO, Processing ticker AEP
# 2024-10-23 21:02:13,802, data_manager.py, 73, INFO, Processing ticker AEP
# 2024-10-23 21:02:13,804, data_manager.py, 109, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:13,804, data_manager.py, 109, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:14,299, data_manager.py, 83, INFO, Saving data for AEP by year
# 2024-10-23 21:02:14,299, data_manager.py, 83, INFO, Saving data for AEP by year
# 2024-10-23 21:02:15,431, data_manager.py, 73, INFO, Processing ticker AXP
# 2024-10-23 21:02:15,431, data_manager.py, 73, INFO, Processing ticker AXP
# 2024-10-23 21:02:15,433, data_manager.py, 109, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:15,433, data_manager.py, 109, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:16,101, data_manager.py, 83, INFO, Saving data for AXP by year
# 2024-10-23 21:02:16,101, data_manager.py, 83, INFO, Saving data for AXP by year
# 2024-10-23 21:02:17,289, data_manager.py, 73, INFO, Processing ticker AIG
# 2024-10-23 21:02:17,289, data_manager.py, 73, INFO, Processing ticker AIG
# 2024-10-23 21:02:17,291, data_manager.py, 109, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:17,291, data_manager.py, 109, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:17,698, data_manager.py, 83, INFO, Saving data for AIG by year
# 2024-10-23 21:02:17,698, data_manager.py, 83, INFO, Saving data for AIG by year
# 2024-10-23 21:02:18,956, data_manager.py, 73, INFO, Processing ticker AMT
# 2024-10-23 21:02:18,956, data_manager.py, 73, INFO, Processing ticker AMT
# 2024-10-23 21:02:18,958, data_manager.py, 109, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:18,958, data_manager.py, 109, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:19,326, data_manager.py, 83, INFO, Saving data for AMT by year
# 2024-10-23 21:02:19,326, data_manager.py, 83, INFO, Saving data for AMT by year
# 2024-10-23 21:02:20,562, data_manager.py, 73, INFO, Processing ticker AWK
# 2024-10-23 21:02:20,562, data_manager.py, 73, INFO, Processing ticker AWK
# 2024-10-23 21:02:20,564, data_manager.py, 109, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:20,564, data_manager.py, 109, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:20,802, data_manager.py, 83, INFO, Saving data for AWK by year
# 2024-10-23 21:02:20,802, data_manager.py, 83, INFO, Saving data for AWK by year
# 2024-10-23 21:02:21,661, data_manager.py, 73, INFO, Processing ticker AMP
# 2024-10-23 21:02:21,661, data_manager.py, 73, INFO, Processing ticker AMP
# 2024-10-23 21:02:21,662, data_manager.py, 109, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:21,662, data_manager.py, 109, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:21,942, data_manager.py, 83, INFO, Saving data for AMP by year
# 2024-10-23 21:02:21,942, data_manager.py, 83, INFO, Saving data for AMP by year
# 2024-10-23 21:02:22,903, data_manager.py, 73, INFO, Processing ticker AME
# 2024-10-23 21:02:22,903, data_manager.py, 73, INFO, Processing ticker AME
# 2024-10-23 21:02:22,906, data_manager.py, 109, INFO, Getting stock price data for AME from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:22,906, data_manager.py, 109, INFO, Getting stock price data for AME from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:23,318, data_manager.py, 83, INFO, Saving data for AME by year
# 2024-10-23 21:02:23,318, data_manager.py, 83, INFO, Saving data for AME by year
# 2024-10-23 21:02:24,515, data_manager.py, 73, INFO, Processing ticker AMGN
# 2024-10-23 21:02:24,515, data_manager.py, 73, INFO, Processing ticker AMGN
# 2024-10-23 21:02:24,517, data_manager.py, 109, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:24,517, data_manager.py, 109, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:24,762, data_manager.py, 83, INFO, Saving data for AMGN by year
# 2024-10-23 21:02:24,762, data_manager.py, 83, INFO, Saving data for AMGN by year
# 2024-10-23 21:02:26,112, data_manager.py, 73, INFO, Processing ticker APH
# 2024-10-23 21:02:26,112, data_manager.py, 73, INFO, Processing ticker APH
# 2024-10-23 21:02:26,114, data_manager.py, 109, INFO, Getting stock price data for APH from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:26,114, data_manager.py, 109, INFO, Getting stock price data for APH from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:26,457, data_manager.py, 83, INFO, Saving data for APH by year
# 2024-10-23 21:02:26,457, data_manager.py, 83, INFO, Saving data for APH by year
# 2024-10-23 21:02:27,727, data_manager.py, 73, INFO, Processing ticker ADI
# 2024-10-23 21:02:27,727, data_manager.py, 73, INFO, Processing ticker ADI
# 2024-10-23 21:02:27,730, data_manager.py, 109, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:27,730, data_manager.py, 109, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:28,077, data_manager.py, 83, INFO, Saving data for ADI by year
# 2024-10-23 21:02:28,077, data_manager.py, 83, INFO, Saving data for ADI by year
# 2024-10-23 21:02:29,293, data_manager.py, 73, INFO, Processing ticker ANSS
# 2024-10-23 21:02:29,293, data_manager.py, 73, INFO, Processing ticker ANSS
# 2024-10-23 21:02:29,295, data_manager.py, 109, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:29,295, data_manager.py, 109, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:29,568, data_manager.py, 83, INFO, Saving data for ANSS by year
# 2024-10-23 21:02:29,568, data_manager.py, 83, INFO, Saving data for ANSS by year
# 2024-10-23 21:02:30,753, data_manager.py, 73, INFO, Processing ticker AON
# 2024-10-23 21:02:30,753, data_manager.py, 73, INFO, Processing ticker AON
# 2024-10-23 21:02:30,756, data_manager.py, 109, INFO, Getting stock price data for AON from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:30,756, data_manager.py, 109, INFO, Getting stock price data for AON from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:31,152, data_manager.py, 83, INFO, Saving data for AON by year
# 2024-10-23 21:02:31,152, data_manager.py, 83, INFO, Saving data for AON by year
# 2024-10-23 21:02:32,336, data_manager.py, 73, INFO, Processing ticker APA
# 2024-10-23 21:02:32,336, data_manager.py, 73, INFO, Processing ticker APA
# 2024-10-23 21:02:32,340, data_manager.py, 109, INFO, Getting stock price data for APA from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:32,340, data_manager.py, 109, INFO, Getting stock price data for APA from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:32,797, data_manager.py, 83, INFO, Saving data for APA by year
# 2024-10-23 21:02:32,797, data_manager.py, 83, INFO, Saving data for APA by year
# 2024-10-23 21:02:33,962, data_manager.py, 73, INFO, Processing ticker AAPL
# 2024-10-23 21:02:33,962, data_manager.py, 73, INFO, Processing ticker AAPL
# 2024-10-23 21:02:33,964, data_manager.py, 109, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:33,964, data_manager.py, 109, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:34,291, data_manager.py, 83, INFO, Saving data for AAPL by year
# 2024-10-23 21:02:34,291, data_manager.py, 83, INFO, Saving data for AAPL by year
# 2024-10-23 21:02:35,642, data_manager.py, 73, INFO, Processing ticker AMAT
# 2024-10-23 21:02:35,642, data_manager.py, 73, INFO, Processing ticker AMAT
# 2024-10-23 21:02:35,645, data_manager.py, 109, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:35,645, data_manager.py, 109, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:36,031, data_manager.py, 83, INFO, Saving data for AMAT by year
# 2024-10-23 21:02:36,031, data_manager.py, 83, INFO, Saving data for AMAT by year
# 2024-10-23 21:02:37,282, data_manager.py, 73, INFO, Processing ticker APTV
# 2024-10-23 21:02:37,282, data_manager.py, 73, INFO, Processing ticker APTV
# 2024-10-23 21:02:37,284, data_manager.py, 109, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:37,284, data_manager.py, 109, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:37,542, data_manager.py, 83, INFO, Saving data for APTV by year
# 2024-10-23 21:02:37,542, data_manager.py, 83, INFO, Saving data for APTV by year
# 2024-10-23 21:02:38,246, data_manager.py, 73, INFO, Processing ticker ACGL
# 2024-10-23 21:02:38,246, data_manager.py, 73, INFO, Processing ticker ACGL
# 2024-10-23 21:02:38,248, data_manager.py, 109, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:38,248, data_manager.py, 109, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:38,550, data_manager.py, 83, INFO, Saving data for ACGL by year
# 2024-10-23 21:02:38,550, data_manager.py, 83, INFO, Saving data for ACGL by year
# 2024-10-23 21:02:39,710, data_manager.py, 73, INFO, Processing ticker ADM
# 2024-10-23 21:02:39,710, data_manager.py, 73, INFO, Processing ticker ADM
# 2024-10-23 21:02:39,712, data_manager.py, 109, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:39,712, data_manager.py, 109, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:40,120, data_manager.py, 83, INFO, Saving data for ADM by year
# 2024-10-23 21:02:40,120, data_manager.py, 83, INFO, Saving data for ADM by year
# 2024-10-23 21:02:41,340, data_manager.py, 73, INFO, Processing ticker ANET
# 2024-10-23 21:02:41,340, data_manager.py, 73, INFO, Processing ticker ANET
# 2024-10-23 21:02:41,342, data_manager.py, 109, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:41,342, data_manager.py, 109, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:41,551, data_manager.py, 83, INFO, Saving data for ANET by year
# 2024-10-23 21:02:41,551, data_manager.py, 83, INFO, Saving data for ANET by year
# 2024-10-23 21:02:42,079, data_manager.py, 73, INFO, Processing ticker AJG
# 2024-10-23 21:02:42,079, data_manager.py, 73, INFO, Processing ticker AJG
# 2024-10-23 21:02:42,081, data_manager.py, 109, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:42,081, data_manager.py, 109, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:42,463, data_manager.py, 83, INFO, Saving data for AJG by year
# 2024-10-23 21:02:42,463, data_manager.py, 83, INFO, Saving data for AJG by year
# 2024-10-23 21:02:43,714, data_manager.py, 73, INFO, Processing ticker AIZ
# 2024-10-23 21:02:43,714, data_manager.py, 73, INFO, Processing ticker AIZ
# 2024-10-23 21:02:43,716, data_manager.py, 109, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:43,716, data_manager.py, 109, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:44,035, data_manager.py, 83, INFO, Saving data for AIZ by year
# 2024-10-23 21:02:44,035, data_manager.py, 83, INFO, Saving data for AIZ by year
# 2024-10-23 21:02:45,050, data_manager.py, 73, INFO, Processing ticker T
# 2024-10-23 21:02:45,050, data_manager.py, 73, INFO, Processing ticker T
# 2024-10-23 21:02:45,053, data_manager.py, 109, INFO, Getting stock price data for T from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:45,053, data_manager.py, 109, INFO, Getting stock price data for T from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:45,512, data_manager.py, 83, INFO, Saving data for T by year
# 2024-10-23 21:02:45,512, data_manager.py, 83, INFO, Saving data for T by year
# 2024-10-23 21:02:46,638, data_manager.py, 73, INFO, Processing ticker ATO
# 2024-10-23 21:02:46,638, data_manager.py, 73, INFO, Processing ticker ATO
# 2024-10-23 21:02:46,640, data_manager.py, 109, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:46,640, data_manager.py, 109, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:47,003, data_manager.py, 83, INFO, Saving data for ATO by year
# 2024-10-23 21:02:47,003, data_manager.py, 83, INFO, Saving data for ATO by year
# 2024-10-23 21:02:48,295, data_manager.py, 73, INFO, Processing ticker ADSK
# 2024-10-23 21:02:48,295, data_manager.py, 73, INFO, Processing ticker ADSK
# 2024-10-23 21:02:48,298, data_manager.py, 109, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:48,298, data_manager.py, 109, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:48,638, data_manager.py, 83, INFO, Saving data for ADSK by year
# 2024-10-23 21:02:48,638, data_manager.py, 83, INFO, Saving data for ADSK by year
# 2024-10-23 21:02:49,898, data_manager.py, 73, INFO, Processing ticker ADP
# 2024-10-23 21:02:49,898, data_manager.py, 73, INFO, Processing ticker ADP
# 2024-10-23 21:02:49,899, data_manager.py, 109, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:49,899, data_manager.py, 109, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:50,289, data_manager.py, 83, INFO, Saving data for ADP by year
# 2024-10-23 21:02:50,289, data_manager.py, 83, INFO, Saving data for ADP by year
# 2024-10-23 21:02:51,439, data_manager.py, 73, INFO, Processing ticker AZO
# 2024-10-23 21:02:51,439, data_manager.py, 73, INFO, Processing ticker AZO
# 2024-10-23 21:02:51,441, data_manager.py, 109, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:51,441, data_manager.py, 109, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:51,691, data_manager.py, 83, INFO, Saving data for AZO by year
# 2024-10-23 21:02:51,691, data_manager.py, 83, INFO, Saving data for AZO by year
# 2024-10-23 21:02:53,048, data_manager.py, 73, INFO, Processing ticker AVB
# 2024-10-23 21:02:53,048, data_manager.py, 73, INFO, Processing ticker AVB
# 2024-10-23 21:02:53,050, data_manager.py, 109, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:53,050, data_manager.py, 109, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:53,465, data_manager.py, 83, INFO, Saving data for AVB by year
# 2024-10-23 21:02:53,465, data_manager.py, 83, INFO, Saving data for AVB by year
# 2024-10-23 21:02:54,639, data_manager.py, 73, INFO, Processing ticker AVY
# 2024-10-23 21:02:54,639, data_manager.py, 73, INFO, Processing ticker AVY
# 2024-10-23 21:02:54,641, data_manager.py, 109, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:54,641, data_manager.py, 109, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:55,048, data_manager.py, 83, INFO, Saving data for AVY by year
# 2024-10-23 21:02:55,048, data_manager.py, 83, INFO, Saving data for AVY by year
# 2024-10-23 21:02:56,182, data_manager.py, 73, INFO, Processing ticker AXON
# 2024-10-23 21:02:56,182, data_manager.py, 73, INFO, Processing ticker AXON
# 2024-10-23 21:02:56,185, data_manager.py, 109, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:56,185, data_manager.py, 109, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:56,505, data_manager.py, 83, INFO, Saving data for AXON by year
# 2024-10-23 21:02:56,505, data_manager.py, 83, INFO, Saving data for AXON by year
# 2024-10-23 21:02:57,688, data_manager.py, 73, INFO, Processing ticker BKR
# 2024-10-23 21:02:57,688, data_manager.py, 73, INFO, Processing ticker BKR
# 2024-10-23 21:02:57,690, data_manager.py, 109, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:57,690, data_manager.py, 109, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:58,093, data_manager.py, 83, INFO, Saving data for BKR by year
# 2024-10-23 21:02:58,093, data_manager.py, 83, INFO, Saving data for BKR by year
# 2024-10-23 21:02:59,360, data_manager.py, 73, INFO, Processing ticker BALL
# 2024-10-23 21:02:59,360, data_manager.py, 73, INFO, Processing ticker BALL
# 2024-10-23 21:02:59,362, data_manager.py, 109, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-10-23
# 2024-10-23 21:02:59,362, data_manager.py, 109, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:02:59,730, data_manager.py, 83, INFO, Saving data for BALL by year
# 2024-10-23 21:02:59,730, data_manager.py, 83, INFO, Saving data for BALL by year
# 2024-10-23 21:03:00,959, data_manager.py, 73, INFO, Processing ticker BAC
# 2024-10-23 21:03:00,959, data_manager.py, 73, INFO, Processing ticker BAC
# 2024-10-23 21:03:00,962, data_manager.py, 109, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-10-23
# 2024-10-23 21:03:00,962, data_manager.py, 109, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:03:01,349, data_manager.py, 83, INFO, Saving data for BAC by year
# 2024-10-23 21:03:01,349, data_manager.py, 83, INFO, Saving data for BAC by year
# 2024-10-23 21:03:02,604, data_manager.py, 73, INFO, Processing ticker BK
# 2024-10-23 21:03:02,604, data_manager.py, 73, INFO, Processing ticker BK
# 2024-10-23 21:03:02,606, data_manager.py, 109, INFO, Getting stock price data for BK from 2000-01-01 to 2024-10-23
# 2024-10-23 21:03:02,606, data_manager.py, 109, INFO, Getting stock price data for BK from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:03:03,004, data_manager.py, 83, INFO, Saving data for BK by year
# 2024-10-23 21:03:03,004, data_manager.py, 83, INFO, Saving data for BK by year
# 2024-10-23 21:03:04,221, data_manager.py, 73, INFO, Processing ticker BBWI
# 2024-10-23 21:03:04,221, data_manager.py, 73, INFO, Processing ticker BBWI
# 2024-10-23 21:03:04,223, data_manager.py, 109, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-10-23
# 2024-10-23 21:03:04,223, data_manager.py, 109, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:03:04,658, data_manager.py, 83, INFO, Saving data for BBWI by year
# 2024-10-23 21:03:04,658, data_manager.py, 83, INFO, Saving data for BBWI by year
# 2024-10-23 21:03:05,850, data_manager.py, 73, INFO, Processing ticker BAX
# 2024-10-23 21:03:05,850, data_manager.py, 73, INFO, Processing ticker BAX
# 2024-10-23 21:03:05,852, data_manager.py, 109, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-10-23
# 2024-10-23 21:03:05,852, data_manager.py, 109, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:03:06,309, data_manager.py, 83, INFO, Saving data for BAX by year
# 2024-10-23 21:03:06,309, data_manager.py, 83, INFO, Saving data for BAX by year
# 2024-10-23 21:03:07,410, data_manager.py, 73, INFO, Processing ticker BDX
# 2024-10-23 21:03:07,410, data_manager.py, 73, INFO, Processing ticker BDX
# 2024-10-23 21:03:07,412, data_manager.py, 109, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-10-23
# 2024-10-23 21:03:07,412, data_manager.py, 109, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:03:07,901, data_manager.py, 83, INFO, Saving data for BDX by year
# 2024-10-23 21:03:07,901, data_manager.py, 83, INFO, Saving data for BDX by year
# 2024-10-23 21:03:09,126, data_manager.py, 73, INFO, Processing ticker BRK.B
# 2024-10-23 21:03:09,126, data_manager.py, 73, INFO, Processing ticker BRK.B
# 2024-10-23 21:03:09,128, data_manager.py, 109, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-10-23
# 2024-10-23 21:03:09,128, data_manager.py, 109, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BRK.B']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# 2024-10-23 21:03:10,526, data_manager.py, 83, INFO, Saving data for BRK.B by year
# 2024-10-23 21:03:10,526, data_manager.py, 83, INFO, Saving data for BRK.B by year
# 2024-10-23 21:03:10,528, data_manager.py, 101, WARNING, No data found for BRK.B
# 2024-10-23 21:03:10,528, data_manager.py, 101, WARNING, No data found for BRK.B
# 2024-10-23 21:03:10,532, data_manager.py, 73, INFO, Processing ticker BBY
# 2024-10-23 21:03:10,532, data_manager.py, 73, INFO, Processing ticker BBY
# 2024-10-23 21:03:10,535, data_manager.py, 109, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-10-23
# 2024-10-23 21:03:10,535, data_manager.py, 109, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:03:10,825, data_manager.py, 83, INFO, Saving data for BBY by year
# 2024-10-23 21:03:10,825, data_manager.py, 83, INFO, Saving data for BBY by year
# 2024-10-23 21:03:12,101, data_manager.py, 73, INFO, Processing ticker BIO
# 2024-10-23 21:03:12,101, data_manager.py, 73, INFO, Processing ticker BIO
# 2024-10-23 21:03:12,103, data_manager.py, 109, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-10-23
# 2024-10-23 21:03:12,103, data_manager.py, 109, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:03:12,340, data_manager.py, 83, INFO, Saving data for BIO by year
# 2024-10-23 21:03:12,340, data_manager.py, 83, INFO, Saving data for BIO by year
# 2024-10-23 21:03:13,669, data_manager.py, 73, INFO, Processing ticker TECH
# 2024-10-23 21:03:13,669, data_manager.py, 73, INFO, Processing ticker TECH
# 2024-10-23 21:03:13,670, data_manager.py, 109, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-10-23
# 2024-10-23 21:03:13,670, data_manager.py, 109, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:03:14,024, data_manager.py, 83, INFO, Saving data for TECH by year
# 2024-10-23 21:03:14,024, data_manager.py, 83, INFO, Saving data for TECH by year
# 2024-10-23 21:03:15,166, data_manager.py, 73, INFO, Processing ticker BIIB
# 2024-10-23 21:03:15,166, data_manager.py, 73, INFO, Processing ticker BIIB
# 2024-10-23 21:03:15,168, data_manager.py, 109, INFO, Getting stock price data for BIIB from 2000-01-01 to 2024-10-23
# 2024-10-23 21:03:15,168, data_manager.py, 109, INFO, Getting stock price data for BIIB from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:03:15,470, data_manager.py, 83, INFO, Saving data for BIIB by year
# 2024-10-23 21:03:15,470, data_manager.py, 83, INFO, Saving data for BIIB by year
# 2024-10-23 21:03:16,817, data_manager.py, 73, INFO, Processing ticker BLK
# 2024-10-23 21:03:16,817, data_manager.py, 73, INFO, Processing ticker BLK
# 2024-10-23 21:03:16,819, data_manager.py, 109, INFO, Getting stock price data for BLK from 2000-01-01 to 2024-10-23
# 2024-10-23 21:03:16,819, data_manager.py, 109, INFO, Getting stock price data for BLK from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:03:17,151, data_manager.py, 83, INFO, Saving data for BLK by year
# 2024-10-23 21:03:17,151, data_manager.py, 83, INFO, Saving data for BLK by year
# 2024-10-23 21:03:18,419, data_manager.py, 73, INFO, Processing ticker BX
# 2024-10-23 21:03:18,419, data_manager.py, 73, INFO, Processing ticker BX
# 2024-10-23 21:03:18,421, data_manager.py, 109, INFO, Getting stock price data for BX from 2000-01-01 to 2024-10-23
# 2024-10-23 21:03:18,421, data_manager.py, 109, INFO, Getting stock price data for BX from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:03:18,649, data_manager.py, 83, INFO, Saving data for BX by year
# 2024-10-23 21:03:18,649, data_manager.py, 83, INFO, Saving data for BX by year
# 2024-10-23 21:03:19,483, data_manager.py, 73, INFO, Processing ticker BA
# 2024-10-23 21:03:19,483, data_manager.py, 73, INFO, Processing ticker BA
# 2024-10-23 21:03:19,484, data_manager.py, 109, INFO, Getting stock price data for BA from 2000-01-01 to 2024-10-23
# 2024-10-23 21:03:19,484, data_manager.py, 109, INFO, Getting stock price data for BA from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:03:19,983, data_manager.py, 83, INFO, Saving data for BA by year
# 2024-10-23 21:03:19,983, data_manager.py, 83, INFO, Saving data for BA by year
# 2024-10-23 21:03:21,182, data_manager.py, 73, INFO, Processing ticker BKNG
# 2024-10-23 21:03:21,182, data_manager.py, 73, INFO, Processing ticker BKNG
# 2024-10-23 21:03:21,184, data_manager.py, 109, INFO, Getting stock price data for BKNG from 2000-01-01 to 2024-10-23
# 2024-10-23 21:03:21,184, data_manager.py, 109, INFO, Getting stock price data for BKNG from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:03:21,523, data_manager.py, 83, INFO, Saving data for BKNG by year
# 2024-10-23 21:03:21,523, data_manager.py, 83, INFO, Saving data for BKNG by year
# 2024-10-23 21:03:22,742, data_manager.py, 73, INFO, Processing ticker BWA
# 2024-10-23 21:03:22,742, data_manager.py, 73, INFO, Processing ticker BWA
# 2024-10-23 21:03:22,744, data_manager.py, 109, INFO, Getting stock price data for BWA from 2000-01-01 to 2024-10-23
# 2024-10-23 21:03:22,744, data_manager.py, 109, INFO, Getting stock price data for BWA from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:03:23,190, data_manager.py, 83, INFO, Saving data for BWA by year
# 2024-10-23 21:03:23,190, data_manager.py, 83, INFO, Saving data for BWA by year
# 2024-10-23 21:03:24,367, data_manager.py, 73, INFO, Processing ticker BXP
# 2024-10-23 21:03:24,367, data_manager.py, 73, INFO, Processing ticker BXP
# 2024-10-23 21:03:24,369, data_manager.py, 109, INFO, Getting stock price data for BXP from 2000-01-01 to 2024-10-23
# 2024-10-23 21:03:24,369, data_manager.py, 109, INFO, Getting stock price data for BXP from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:03:24,780, data_manager.py, 83, INFO, Saving data for BXP by year
# 2024-10-23 21:03:24,780, data_manager.py, 83, INFO, Saving data for BXP by year
# 2024-10-23 21:03:26,014, data_manager.py, 73, INFO, Processing ticker BSX
# 2024-10-23 21:03:26,014, data_manager.py, 73, INFO, Processing ticker BSX
# 2024-10-23 21:03:26,016, data_manager.py, 109, INFO, Getting stock price data for BSX from 2000-01-01 to 2024-10-23
# 2024-10-23 21:03:26,016, data_manager.py, 109, INFO, Getting stock price data for BSX from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:03:26,275, data_manager.py, 83, INFO, Saving data for BSX by year
# 2024-10-23 21:03:26,275, data_manager.py, 83, INFO, Saving data for BSX by year
# 2024-10-23 21:03:27,589, data_manager.py, 73, INFO, Processing ticker BMY
# 2024-10-23 21:03:27,589, data_manager.py, 73, INFO, Processing ticker BMY
# 2024-10-23 21:03:27,590, data_manager.py, 109, INFO, Getting stock price data for BMY from 2000-01-01 to 2024-10-23
# 2024-10-23 21:03:27,590, data_manager.py, 109, INFO, Getting stock price data for BMY from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:03:28,112, data_manager.py, 83, INFO, Saving data for BMY by year
# 2024-10-23 21:03:28,112, data_manager.py, 83, INFO, Saving data for BMY by year
# 2024-10-23 21:03:29,278, data_manager.py, 73, INFO, Processing ticker AVGO
# 2024-10-23 21:03:29,278, data_manager.py, 73, INFO, Processing ticker AVGO
# 2024-10-23 21:03:29,281, data_manager.py, 109, INFO, Getting stock price data for AVGO from 2000-01-01 to 2024-10-23
# 2024-10-23 21:03:29,281, data_manager.py, 109, INFO, Getting stock price data for AVGO from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:03:29,570, data_manager.py, 83, INFO, Saving data for AVGO by year
# 2024-10-23 21:03:29,570, data_manager.py, 83, INFO, Saving data for AVGO by year
# 2024-10-23 21:03:30,369, data_manager.py, 73, INFO, Processing ticker BR
# 2024-10-23 21:03:30,369, data_manager.py, 73, INFO, Processing ticker BR
# 2024-10-23 21:03:30,372, data_manager.py, 109, INFO, Getting stock price data for BR from 2000-01-01 to 2024-10-23
# 2024-10-23 21:03:30,372, data_manager.py, 109, INFO, Getting stock price data for BR from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:03:30,594, data_manager.py, 83, INFO, Saving data for BR by year
# 2024-10-23 21:03:30,594, data_manager.py, 83, INFO, Saving data for BR by year
# 2024-10-23 21:03:31,498, data_manager.py, 73, INFO, Processing ticker BRO
# 2024-10-23 21:03:31,498, data_manager.py, 73, INFO, Processing ticker BRO
# ...
# 2024-10-23 21:13:26,139, data_manager.py, 109, INFO, Getting stock price data for WAB from 2000-01-01 to 2024-10-23
# 2024-10-23 21:13:26,139, data_manager.py, 109, INFO, Getting stock price data for WAB from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:13:26,538, data_manager.py, 83, INFO, Saving data for WAB by year
# 2024-10-23 21:13:26,538, data_manager.py, 83, INFO, Saving data for WAB by year
# 2024-10-23 21:13:27,644, data_manager.py, 73, INFO, Processing ticker WBA
# 2024-10-23 21:13:27,644, data_manager.py, 73, INFO, Processing ticker WBA
# 2024-10-23 21:13:27,646, data_manager.py, 109, INFO, Getting stock price data for WBA from 2000-01-01 to 2024-10-23
# 2024-10-23 21:13:27,646, data_manager.py, 109, INFO, Getting stock price data for WBA from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:13:28,054, data_manager.py, 83, INFO, Saving data for WBA by year
# 2024-10-23 21:13:28,054, data_manager.py, 83, INFO, Saving data for WBA by year
# 2024-10-23 21:13:29,345, data_manager.py, 73, INFO, Processing ticker WMT
# 2024-10-23 21:13:29,345, data_manager.py, 73, INFO, Processing ticker WMT
# 2024-10-23 21:13:29,347, data_manager.py, 109, INFO, Getting stock price data for WMT from 2000-01-01 to 2024-10-23
# 2024-10-23 21:13:29,347, data_manager.py, 109, INFO, Getting stock price data for WMT from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:13:29,774, data_manager.py, 83, INFO, Saving data for WMT by year
# 2024-10-23 21:13:29,774, data_manager.py, 83, INFO, Saving data for WMT by year
# 2024-10-23 21:13:30,898, data_manager.py, 73, INFO, Processing ticker DIS
# 2024-10-23 21:13:30,898, data_manager.py, 73, INFO, Processing ticker DIS
# 2024-10-23 21:13:30,900, data_manager.py, 109, INFO, Getting stock price data for DIS from 2000-01-01 to 2024-10-23
# 2024-10-23 21:13:30,900, data_manager.py, 109, INFO, Getting stock price data for DIS from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:13:31,364, data_manager.py, 83, INFO, Saving data for DIS by year
# 2024-10-23 21:13:31,364, data_manager.py, 83, INFO, Saving data for DIS by year
# 2024-10-23 21:13:32,515, data_manager.py, 73, INFO, Processing ticker WBD
# 2024-10-23 21:13:32,515, data_manager.py, 73, INFO, Processing ticker WBD
# 2024-10-23 21:13:32,517, data_manager.py, 109, INFO, Getting stock price data for WBD from 2000-01-01 to 2024-10-23
# 2024-10-23 21:13:32,517, data_manager.py, 109, INFO, Getting stock price data for WBD from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:13:32,784, data_manager.py, 83, INFO, Saving data for WBD by year
# 2024-10-23 21:13:32,784, data_manager.py, 83, INFO, Saving data for WBD by year
# 2024-10-23 21:13:33,767, data_manager.py, 73, INFO, Processing ticker WM
# 2024-10-23 21:13:33,767, data_manager.py, 73, INFO, Processing ticker WM
# 2024-10-23 21:13:33,768, data_manager.py, 109, INFO, Getting stock price data for WM from 2000-01-01 to 2024-10-23
# 2024-10-23 21:13:33,768, data_manager.py, 109, INFO, Getting stock price data for WM from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:13:34,123, data_manager.py, 83, INFO, Saving data for WM by year
# 2024-10-23 21:13:34,123, data_manager.py, 83, INFO, Saving data for WM by year
# 2024-10-23 21:13:35,227, data_manager.py, 73, INFO, Processing ticker WAT
# 2024-10-23 21:13:35,227, data_manager.py, 73, INFO, Processing ticker WAT
# 2024-10-23 21:13:35,230, data_manager.py, 109, INFO, Getting stock price data for WAT from 2000-01-01 to 2024-10-23
# 2024-10-23 21:13:35,230, data_manager.py, 109, INFO, Getting stock price data for WAT from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:13:35,502, data_manager.py, 83, INFO, Saving data for WAT by year
# 2024-10-23 21:13:35,502, data_manager.py, 83, INFO, Saving data for WAT by year
# 2024-10-23 21:13:36,919, data_manager.py, 73, INFO, Processing ticker WEC
# 2024-10-23 21:13:36,919, data_manager.py, 73, INFO, Processing ticker WEC
# 2024-10-23 21:13:36,921, data_manager.py, 109, INFO, Getting stock price data for WEC from 2000-01-01 to 2024-10-23
# 2024-10-23 21:13:36,921, data_manager.py, 109, INFO, Getting stock price data for WEC from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:13:37,426, data_manager.py, 83, INFO, Saving data for WEC by year
# 2024-10-23 21:13:37,426, data_manager.py, 83, INFO, Saving data for WEC by year
# 2024-10-23 21:13:38,546, data_manager.py, 73, INFO, Processing ticker WFC
# 2024-10-23 21:13:38,546, data_manager.py, 73, INFO, Processing ticker WFC
# 2024-10-23 21:13:38,548, data_manager.py, 109, INFO, Getting stock price data for WFC from 2000-01-01 to 2024-10-23
# 2024-10-23 21:13:38,548, data_manager.py, 109, INFO, Getting stock price data for WFC from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:13:39,019, data_manager.py, 83, INFO, Saving data for WFC by year
# 2024-10-23 21:13:39,019, data_manager.py, 83, INFO, Saving data for WFC by year
# 2024-10-23 21:13:40,147, data_manager.py, 73, INFO, Processing ticker WELL
# 2024-10-23 21:13:40,147, data_manager.py, 73, INFO, Processing ticker WELL
# 2024-10-23 21:13:40,149, data_manager.py, 109, INFO, Getting stock price data for WELL from 2000-01-01 to 2024-10-23
# 2024-10-23 21:13:40,149, data_manager.py, 109, INFO, Getting stock price data for WELL from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:13:40,515, data_manager.py, 83, INFO, Saving data for WELL by year
# 2024-10-23 21:13:40,515, data_manager.py, 83, INFO, Saving data for WELL by year
# 2024-10-23 21:13:41,752, data_manager.py, 73, INFO, Processing ticker WST
# 2024-10-23 21:13:41,752, data_manager.py, 73, INFO, Processing ticker WST
# 2024-10-23 21:13:41,755, data_manager.py, 109, INFO, Getting stock price data for WST from 2000-01-01 to 2024-10-23
# 2024-10-23 21:13:41,755, data_manager.py, 109, INFO, Getting stock price data for WST from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:13:42,095, data_manager.py, 83, INFO, Saving data for WST by year
# 2024-10-23 21:13:42,095, data_manager.py, 83, INFO, Saving data for WST by year
# 2024-10-23 21:13:43,251, data_manager.py, 73, INFO, Processing ticker WDC
# 2024-10-23 21:13:43,251, data_manager.py, 73, INFO, Processing ticker WDC
# 2024-10-23 21:13:43,253, data_manager.py, 109, INFO, Getting stock price data for WDC from 2000-01-01 to 2024-10-23
# 2024-10-23 21:13:43,253, data_manager.py, 109, INFO, Getting stock price data for WDC from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:13:43,480, data_manager.py, 83, INFO, Saving data for WDC by year
# 2024-10-23 21:13:43,480, data_manager.py, 83, INFO, Saving data for WDC by year
# 2024-10-23 21:13:44,798, data_manager.py, 73, INFO, Processing ticker WRK
# 2024-10-23 21:13:44,798, data_manager.py, 73, INFO, Processing ticker WRK
# 2024-10-23 21:13:44,800, data_manager.py, 109, INFO, Getting stock price data for WRK from 2000-01-01 to 2024-10-23
# 2024-10-23 21:13:44,800, data_manager.py, 109, INFO, Getting stock price data for WRK from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WRK']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# 2024-10-23 21:13:46,171, data_manager.py, 83, INFO, Saving data for WRK by year
# 2024-10-23 21:13:46,171, data_manager.py, 83, INFO, Saving data for WRK by year
# 2024-10-23 21:13:46,173, data_manager.py, 101, WARNING, No data found for WRK
# 2024-10-23 21:13:46,173, data_manager.py, 101, WARNING, No data found for WRK
# 2024-10-23 21:13:46,175, data_manager.py, 73, INFO, Processing ticker WY
# 2024-10-23 21:13:46,175, data_manager.py, 73, INFO, Processing ticker WY
# 2024-10-23 21:13:46,178, data_manager.py, 109, INFO, Getting stock price data for WY from 2000-01-01 to 2024-10-23
# 2024-10-23 21:13:46,178, data_manager.py, 109, INFO, Getting stock price data for WY from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:13:46,607, data_manager.py, 83, INFO, Saving data for WY by year
# 2024-10-23 21:13:46,607, data_manager.py, 83, INFO, Saving data for WY by year
# 2024-10-23 21:13:48,019, data_manager.py, 73, INFO, Processing ticker WHR
# 2024-10-23 21:13:48,019, data_manager.py, 73, INFO, Processing ticker WHR
# 2024-10-23 21:13:48,021, data_manager.py, 109, INFO, Getting stock price data for WHR from 2000-01-01 to 2024-10-23
# 2024-10-23 21:13:48,021, data_manager.py, 109, INFO, Getting stock price data for WHR from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:13:48,468, data_manager.py, 83, INFO, Saving data for WHR by year
# 2024-10-23 21:13:48,468, data_manager.py, 83, INFO, Saving data for WHR by year
# 2024-10-23 21:13:49,660, data_manager.py, 73, INFO, Processing ticker WMB
# 2024-10-23 21:13:49,660, data_manager.py, 73, INFO, Processing ticker WMB
# 2024-10-23 21:13:49,663, data_manager.py, 109, INFO, Getting stock price data for WMB from 2000-01-01 to 2024-10-23
# 2024-10-23 21:13:49,663, data_manager.py, 109, INFO, Getting stock price data for WMB from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:13:50,045, data_manager.py, 83, INFO, Saving data for WMB by year
# 2024-10-23 21:13:50,045, data_manager.py, 83, INFO, Saving data for WMB by year
# 2024-10-23 21:13:51,338, data_manager.py, 73, INFO, Processing ticker WTW
# 2024-10-23 21:13:51,338, data_manager.py, 73, INFO, Processing ticker WTW
# 2024-10-23 21:13:51,341, data_manager.py, 109, INFO, Getting stock price data for WTW from 2000-01-01 to 2024-10-23
# 2024-10-23 21:13:51,341, data_manager.py, 109, INFO, Getting stock price data for WTW from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:13:51,626, data_manager.py, 83, INFO, Saving data for WTW by year
# 2024-10-23 21:13:51,626, data_manager.py, 83, INFO, Saving data for WTW by year
# 2024-10-23 21:13:52,823, data_manager.py, 73, INFO, Processing ticker GWW
# 2024-10-23 21:13:52,823, data_manager.py, 73, INFO, Processing ticker GWW
# 2024-10-23 21:13:52,825, data_manager.py, 109, INFO, Getting stock price data for GWW from 2000-01-01 to 2024-10-23
# 2024-10-23 21:13:52,825, data_manager.py, 109, INFO, Getting stock price data for GWW from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:13:53,105, data_manager.py, 83, INFO, Saving data for GWW by year
# 2024-10-23 21:13:53,105, data_manager.py, 83, INFO, Saving data for GWW by year
# 2024-10-23 21:13:54,375, data_manager.py, 73, INFO, Processing ticker WYNN
# 2024-10-23 21:13:54,375, data_manager.py, 73, INFO, Processing ticker WYNN
# 2024-10-23 21:13:54,377, data_manager.py, 109, INFO, Getting stock price data for WYNN from 2000-01-01 to 2024-10-23
# 2024-10-23 21:13:54,377, data_manager.py, 109, INFO, Getting stock price data for WYNN from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:13:54,696, data_manager.py, 83, INFO, Saving data for WYNN by year
# 2024-10-23 21:13:54,696, data_manager.py, 83, INFO, Saving data for WYNN by year
# 2024-10-23 21:13:55,918, data_manager.py, 73, INFO, Processing ticker XEL
# 2024-10-23 21:13:55,918, data_manager.py, 73, INFO, Processing ticker XEL
# 2024-10-23 21:13:55,921, data_manager.py, 109, INFO, Getting stock price data for XEL from 2000-01-01 to 2024-10-23
# 2024-10-23 21:13:55,921, data_manager.py, 109, INFO, Getting stock price data for XEL from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:13:56,381, data_manager.py, 83, INFO, Saving data for XEL by year
# 2024-10-23 21:13:56,381, data_manager.py, 83, INFO, Saving data for XEL by year
# 2024-10-23 21:13:57,590, data_manager.py, 73, INFO, Processing ticker XYL
# 2024-10-23 21:13:57,590, data_manager.py, 73, INFO, Processing ticker XYL
# 2024-10-23 21:13:57,592, data_manager.py, 109, INFO, Getting stock price data for XYL from 2000-01-01 to 2024-10-23
# 2024-10-23 21:13:57,592, data_manager.py, 109, INFO, Getting stock price data for XYL from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:13:57,864, data_manager.py, 83, INFO, Saving data for XYL by year
# 2024-10-23 21:13:57,864, data_manager.py, 83, INFO, Saving data for XYL by year
# 2024-10-23 21:13:58,522, data_manager.py, 73, INFO, Processing ticker YUM
# 2024-10-23 21:13:58,522, data_manager.py, 73, INFO, Processing ticker YUM
# 2024-10-23 21:13:58,524, data_manager.py, 109, INFO, Getting stock price data for YUM from 2000-01-01 to 2024-10-23
# 2024-10-23 21:13:58,524, data_manager.py, 109, INFO, Getting stock price data for YUM from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:13:58,824, data_manager.py, 83, INFO, Saving data for YUM by year
# 2024-10-23 21:13:58,824, data_manager.py, 83, INFO, Saving data for YUM by year
# 2024-10-23 21:14:00,117, data_manager.py, 73, INFO, Processing ticker ZBRA
# 2024-10-23 21:14:00,117, data_manager.py, 73, INFO, Processing ticker ZBRA
# 2024-10-23 21:14:00,120, data_manager.py, 109, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-10-23
# 2024-10-23 21:14:00,120, data_manager.py, 109, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:14:00,364, data_manager.py, 83, INFO, Saving data for ZBRA by year
# 2024-10-23 21:14:00,364, data_manager.py, 83, INFO, Saving data for ZBRA by year
# 2024-10-23 21:14:01,593, data_manager.py, 73, INFO, Processing ticker ZBH
# 2024-10-23 21:14:01,593, data_manager.py, 73, INFO, Processing ticker ZBH
# 2024-10-23 21:14:01,596, data_manager.py, 109, INFO, Getting stock price data for ZBH from 2000-01-01 to 2024-10-23
# 2024-10-23 21:14:01,596, data_manager.py, 109, INFO, Getting stock price data for ZBH from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:14:01,904, data_manager.py, 83, INFO, Saving data for ZBH by year
# 2024-10-23 21:14:01,904, data_manager.py, 83, INFO, Saving data for ZBH by year
# 2024-10-23 21:14:03,032, data_manager.py, 73, INFO, Processing ticker ZION
# 2024-10-23 21:14:03,032, data_manager.py, 73, INFO, Processing ticker ZION
# 2024-10-23 21:14:03,034, data_manager.py, 109, INFO, Getting stock price data for ZION from 2000-01-01 to 2024-10-23
# 2024-10-23 21:14:03,034, data_manager.py, 109, INFO, Getting stock price data for ZION from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:14:03,430, data_manager.py, 83, INFO, Saving data for ZION by year
# 2024-10-23 21:14:03,430, data_manager.py, 83, INFO, Saving data for ZION by year
# 2024-10-23 21:14:04,894, data_manager.py, 73, INFO, Processing ticker ZTS
# 2024-10-23 21:14:04,894, data_manager.py, 73, INFO, Processing ticker ZTS
# 2024-10-23 21:14:04,896, data_manager.py, 109, INFO, Getting stock price data for ZTS from 2000-01-01 to 2024-10-23
# 2024-10-23 21:14:04,896, data_manager.py, 109, INFO, Getting stock price data for ZTS from 2000-01-01 to 2024-10-23
# [*********************100%***********************]  1 of 1 completed
# 2024-10-23 21:14:05,113, data_manager.py, 83, INFO, Saving data for ZTS by year
# 2024-10-23 21:14:05,113, data_manager.py, 83, INFO, Saving data for ZTS by year

# %% [markdown]
# Finally, add features to our data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2024-10-23 21:49:19,666, data_manager.py, 121, INFO, Creating features data.
# 2024-10-23 21:49:19,666, data_manager.py, 121, INFO, Creating features data.
# 2024-10-23 21:49:19,673, data_manager.py, 132, INFO, Loading price data from ../../05_src/data/prices/
# 2024-10-23 21:49:19,673, data_manager.py, 132, INFO, Loading price data from ../../05_src/data/prices/
# c:\Users\Test\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\core.py:5517: UserWarning: New index has same name as existing, this is a no-op.
#   warnings.warn(
# 2024-10-23 21:49:41,534, data_manager.py, 140, INFO, Creating features
# 2024-10-23 21:49:41,534, data_manager.py, 140, INFO, Creating features
# c:\Users\Test\production\01_materials\labs\../../05_src\data_manager.py:142: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   features = (price_dd
# 2024-10-23 21:49:42,119, data_manager.py, 158, INFO, Creating target
# 2024-10-23 21:49:42,119, data_manager.py, 158, INFO, Creating target
# c:\Users\Test\production\01_materials\labs\../../05_src\data_manager.py:159: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   self.features = (self.features.groupby('ticker', group_keys=False).apply(
# 2024-10-23 21:49:42,268, data_manager.py, 168, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
# 2024-10-23 21:49:42,268, data_manager.py, 168, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
